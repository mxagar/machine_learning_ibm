# %% [markdown]
# # 8 Deep Learning with Keras

# %% [markdown]
# ## 8.3 Custom Datasets

# %% [markdown]
# #### Cats and Dogs Dataset
#
# Download the dataset:
# `https://drive.google.com/file/d/1U6RtBhML-Lj0w2suve0UhQmwcF5pfJCm/view`
#
# **Datasets for classification should have this folder structure for Keras**:
# ```bash
# train/
#     class_1/
#         file_1.jpg
#         file_2.jpg
#         ...
#     class_2/
#     ...
#     class_n/
# test/
#     class_1/
#     class_2/
#     ...
#     class_n/
# ```

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
path = './'
img = cv2.imread(path+'CATS_DOGS/train/CAT/0.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
img = cv2.imread(path+'CATS_DOGS/train/DOG/2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (199, 188, 3)

# %%
img.max()
# Out:
# 255

# %% [markdown]
# **IMPORTANT NOTE**: all files have a different shape; we need to standardize them!

# %%
# Data augmentation: for more robust and generalizable trainings
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# We pass max absolute values of ranges for data augmentation
# rotation: degrees by which image can be rotated
# width, height shift: % that the image width/height can be changed
# rescale: normalization = divide by max pixel value
# shear: % by which image can be stretched from the diagonal
# zoom: % of image augmenation
# horizontal flip: flip also images?
# fill mode: when pixels are created/removed (eg., when rotating), which values do we take?
image_gen = ImageDataGenerator(rotation_range=30,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              rescale=1/255,
                              shear_range=0.2,
                              zoom_range=0.2,
                              horizontal_flip=True,
                              fill_mode='nearest')

# %%
# We can apply this augmentation transform image-wise easily!
# Every time we call it, we have a slighthly different transformed image
plt.imshow(image_gen.random_transform(img))

# %%
# We define the input shape
# All images are going to be resized to that shape
input_shape = (150, 150, 3)

# %%
# In order to apply data augmentation, we create an iterator on the dataset (for both train & test)
# IMPORTANT NOTE: we need to have the aforementioned structure within each train/test folder: one folder per class
image_gen.flow_from_directory(path+'CATS_DOGS/train')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(path+'CATS_DOGS/test')
# Out:
# Found 6251 images belonging to 2 classes.

# %% [markdown]
# #### Build Model & Train

# %% [markdown]
# Note: In the newsest versions there hasbeen an update in the API sysntax, eg., `MaxPooling2D` instead of `MaxPool2D`.

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Activation, Dropout, Flatten, Conv2D, Dense, MaxPooling2D

# %%
model = Sequential()

# Convolution + Max-Pooling 1
model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=input_shape, activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Convolution + Max-Pooling 2 (once more, because images are quite complex)
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Convolution + Max-Pooling 3 (once more, because images are quite complex)
model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128))
model.add(Activation('relu')) # that's a new feature: we can add activaton separately!

model.add(Dropout(0.5)) # Dropout layer: 50% of neurons shut down randomly

model.add(Dense(1)) # Binary: Cat / Dog?
model.add(Activation('softmax'))

model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9248)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1183872
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,203,393
# Trainable params: 1,203,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **IMPORTANT NOTE: We could apply early stopping here too using the test split as the validation set; look at notebook 08_2.**

# %%
# We define also a batch size
# Images are going to be delivered in batches
# A standard size is 16
batch_size = 16

# %%
train_image_gen = image_gen.flow_from_directory(path+'CATS_DOGS/train',
                                               target_size=input_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory(path+'CATS_DOGS/test',
                                               target_size=input_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 6251 images belonging to 2 classes.

# %%
# We can get class/category names from folder names
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
# TRAIN
# usually an epoch is a complete pass of all training images
# if we define steps_per_epoch, then,
# epoch: steps_per_epoch x batch_size images, not all of them
# We can also pass the validation/test split here to check/prevent overfitting
# Very low values are used here to get a fast training; if done seriously, use higher commented values
results = model.fit_generator(train_image_gen,
                    epochs=150, # 150
                    steps_per_epoch=1, # 1000
                    validation_data=test_image_gen,
                    validation_steps=1) # 300
# Out:
# Epoch 1/150
# 1/1 [==============================] - 1s 1s/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 2/150
# 1/1 [==============================] - 1s 966ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 3/150
# 1/1 [==============================] - 1s 949ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 4/150
# 1/1 [==============================] - 1s 952ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 5/150
# 1/1 [==============================] - 1s 946ms/step - loss: 9.5833 - accuracy: 0.3750 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 6/150
# 1/1 [==============================] - 1s 936ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 7/150
# 1/1 [==============================] - 1s 1s/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 8/150
# 1/1 [==============================] - 1s 1s/step - loss: 5.7500 - accuracy: 0.6250 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 9/150
# 1/1 [==============================] - 1s 964ms/step - loss: 9.5833 - accuracy: 0.3750 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 10/150
# 1/1 [==============================] - 1s 991ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 11/150
# 1/1 [==============================] - 1s 995ms/step - loss: 12.4583 - accuracy: 0.1875 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 12/150
# 1/1 [==============================] - 1s 984ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 13/150
# 1/1 [==============================] - 1s 979ms/step - loss: 11.4999 - accuracy: 0.2500 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 14/150
# 1/1 [==============================] - 1s 948ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 15/150
# 1/1 [==============================] - 1s 952ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 16/150
# 1/1 [==============================] - 1s 964ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 17/150
# 1/1 [==============================] - 1s 959ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 18/150
# 1/1 [==============================] - 1s 958ms/step - loss: 9.5833 - accuracy: 0.3750 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 19/150
# 1/1 [==============================] - 1s 989ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 20/150
# 1/1 [==============================] - 1s 946ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch
- val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 124/150
# 1/1 [==============================] - 1s 952ms/step - loss: 5.7500 - accuracy: 0.6250 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 125/150
# 1/1 [==============================] - 1s 976ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 126/150
# 1/1 [==============================] - 1s 1s/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 127/150
# 1/1 [==============================] - 1s 955ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 128/150
# 1/1 [==============================] - 1s 970ms/step - loss: 5.7500 - accuracy: 0.6250 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 129/150
# 1/1 [==============================] - 1s 983ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 130/150
# 1/1 [==============================] - 1s 1s/step - loss: 3.8333 - accuracy: 0.7500 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 131/150
# 1/1 [==============================] - 1s 969ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 132/150
# 1/1 [==============================] - 1s 959ms/step - loss: 4.7916 - accuracy: 0.6875 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 133/150
# 1/1 [==============================] - 1s 948ms/step - loss: 5.7500 - accuracy: 0.6250 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 134/150
# 1/1 [==============================] - 1s 960ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 135/150
# 1/1 [==============================] - 1s 951ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 136/150
# 1/1 [==============================] - 1s 941ms/step - loss: 4.7916 - accuracy: 0.6875 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 137/150
# 1/1 [==============================] - 1s 942ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 138/150
# 1/1 [==============================] - 1s 958ms/step - loss: 9.5833 - accuracy: 0.3750 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 139/150
# 1/1 [==============================] - 1s 965ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 140/150
# 1/1 [==============================] - 1s 960ms/step - loss: 10.5416 - accuracy: 0.3125 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 141/150
# 1/1 [==============================] - 1s 983ms/step - loss: 5.7500 - accuracy: 0.6250 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 142/150
# 1/1 [==============================] - 1s 990ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 143/150
# 1/1 [==============================] - 1s 979ms/step - loss: 4.7916 - accuracy: 0.6875 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 144/150
# 1/1 [==============================] - 1s 953ms/step - loss: 6.7083 - accuracy: 0.5625 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 145/150
# 1/1 [==============================] - 1s 979ms/step - loss: 9.5833 - accuracy: 0.3750 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 146/150
# 1/1 [==============================] - 1s 947ms/step - loss: 2.8750 - accuracy: 0.8125 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 147/150
# 1/1 [==============================] - 1s 966ms/step - loss: 7.6666 - accuracy: 0.5000 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 148/150
# 1/1 [==============================] - 1s 959ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 149/150
# 1/1 [==============================] - 1s 973ms/step - loss: 5.7500 - accuracy: 0.6250 - val_loss: 5.7500 - val_accuracy: 0.6250
# Epoch 150/150
# 1/1 [==============================] - 1s 948ms/step - loss: 8.6249 - accuracy: 0.4375 - val_loss: 5.7500 - val_accuracy: 0.6250

# %% [markdown]
# We can get warning during training because some images cannot be opened/read (eg., because they are corrupt). We can just ignore them. Optionally, we can add these lines:
#
# ```python
# import warnings
# warnings.filterwarnings('ignore')
# ```

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
# We can get the evolution of the accuracy during training and plot it!
results.history['accuracy']
# Out:
# [0.5,
#  0.5625,
#  0.5625,
#  0.5625,
#  0.375,
#  0.5,
#  0.4375,
#  0.625,
#  0.375,
#  0.4375,
#  0.1875,
#  0.4375,
#  0.25,
#  0.4375,
#  0.5625,
#  0.4375,
#  0.5625,
#  0.375,
#  0.5,
#  0.5,
#  0.1875,
#  0.5,
#  0.5625,
#  0.4375,
#  0.5,
#  0.5625,
#  0.5,
#  0.375,
#  0.375,
#  0.4375,
#  0.375,
#  0.5,
#  0.5,
#  0.3125,
#  0.5625,
#  0.25,
#  0.5,
#  0.4375,
#  0.4375,
#  0.75,
#  0.75,
#  0.4375,
#  0.5625,
#  0.5,
#  0.875,
#  0.5,
#  0.5,
#  0.4375,
#  0.5,
#  0.625,
#  0.375,
#  0.375,
#  0.625,
#  0.625,
#  0.5625,
#  0.6875,
#  0.6875,
#  0.5625,
#  0.4375,
#  0.5,
#  0.5,
#  0.5625,
#  0.375,
#  0.5625,
#  0.3125,
#  0.375,
#  0.375,
#  0.25,
#  0.5625,
#  0.375,
#  0.8125,
#  0.8125,
#  0.625,
#  0.4375,
#  0.625,
#  0.5,
#  0.375,
#  0.4375,
#  0.3125,
#  0.75,
#  0.4375,
#  0.5625,
#  0.5625,
#  0.375,
#  0.375,
#  0.3125,
#  0.5625,
#  0.4375,
#  0.3125,
#  0.25,
#  0.4375,
#  0.5,
#  0.625,
#  0.5,
#  0.4375,
#  0.5,
#  0.375,
#  0.375,
#  0.625,
#  0.6875,
#  0.625,
#  0.5625,
#  0.4375,
#  0.625,
#  0.375,
#  0.5,
#  0.4375,
#  0.375,
#  0.5,
#  0.375,
#  0.5,
#  0.4375,
#  0.375,
#  0.375,
#  0.3125,
#  0.375,
#  0.25,
#  0.75,
#  0.5,
#  0.625,
#  0.375,
#  0.4375,
#  0.4375,
#  0.625,
#  0.4375,
#  0.5,
#  0.5,
#  0.625,
#  0.4375,
#  0.75,
#  0.5,
#  0.6875,
#  0.625,
#  0.5,
#  0.5625,
#  0.6875,
#  0.5,
#  0.375,
#  0.5625,
#  0.3125,
#  0.625,
#  0.5,
#  0.6875,
#  0.5625,
#  0.375,
#  0.8125,
#  0.5,
#  0.4375,
#  0.625,
#  0.4375]

# %%
plt.plot(results.history['accuracy'])

# %% [markdown]
# #### Inference

# %% [markdown]
# Usually, we need to train our model with a considerable amount of epochs. Therefore, I load a pre-trained model.

# %%
from tensorflow.keras.models import load_model

# %%
new_model = load_model('cat_dog_100epochs.h5')

# %%
img = path + 'CATS_DOGS/test/DOG/10005.jpg'

# %% [markdown]
# We need to resize it to the target size!

# %%
from tensorflow.keras.preprocessing import image

# %%
# We can load the image and resize it automatically
# BUT: the image is not a numpy array, so it must be converted
img = image.load_img(img, target_size=input_shape[:2])

# %%
plt.imshow(img)

# %%
# We need to convert it to a numpy array manually
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (150, 150, 3)

# %%
# And we need to give the image the shape (Sample, W, H, C) = (1, W, H, C) = (1, 150, 150, 3)
import numpy as np
img = np.expand_dims(img, axis=0)

# %%
img.shape
# Out:
# (1, 150, 150, 3)

# %%
# Class 0/1 inferred
result = model.predict_classes(img)

# %%
result
# Out:
# array([[1]], dtype=int32)

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %%
# Raw probability should be predicted
result = model.predict(img)

# %%
result
# Out:
# array([[1.]], dtype=float32)
